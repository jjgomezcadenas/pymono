# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import os
import tqdm
from collections import namedtuple

# %% [markdown]
# ## Functions

# %%
def histoplot(var, xlabel, ylabel, bins=100, figsize=(4,4), title=""):
    fig, ax = plt.subplots(1, 1, figsize=(4,4))
    h = plt.hist(var,bins)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(title)
    return h[0],h[1]

# %%
def prgroup(grdf, ng=1):
    i = 1
    for name, group in grdf:
        print(f"Group: {name}")
        print(group, "\n")
        i+=1
        if i > ng:
            break

# %%
def event_ekin(df):
    grdf = df.groupby('event_id')
    ekin = grdf['kin_energy'].sum()
    return ekin

# %%
def event_size(df):
    return len(np.unique(df.event_id))

# %%
def xindex(x,sx):
    return np.floor((x + xmin +dx)/sx)

def yindex(x, sy):
    return np.floor((x + ymin +dy)/sy)

def zindex(x, sz):
    return np.floor((x - zmin)/sz)

# %%
def voxelize(gdfx,mcrst,sx,sy,sz,ecut,case='pixel'):
    gdf = gdfx.copy()
    nx = int(mcrst.dx/sx)
    ny = int(mcrst.dy/sy)
    nz = int(mcrst.dz/sz)
    
    print(f"nx = {nx}, ny = {ny}, nz = {nz}")
    print(f"number of voxels = {nx*ny*nz}")
    print(f"index for xmin ={xindex(mcrst.xmin, sx)} index for xmax ={xindex(mcrst.xmax, sx)}")
    print(f"index for ymin ={yindex(mcrst.ymin, sy)} index for ymax ={yindex(mcrst.ymax, sy)}")
    print(f"index for zmin ={zindex(mcrst.zmin, sz)} index for zmax ={zindex(mcrst.zmax, sz)}")

    gdf["ix"]= xindex(gdf.final_x.values, sx).astype(int)
    gdf["iy"]= yindex(gdf.final_y.values, sy).astype(int)
    gdf["iz"]= zindex(gdf.final_z.values, sz).astype(int)

    if case == 'pixel':
        grdf = gdf.groupby(['event_id', 'ix', 'iy'])
    else:
         grdf = gdf.groupby(['event_id', 'ix', 'iy', 'iz'])

    gdf = grdf.agg(
                ebox = ('kin_energy', 'sum'),
                tbox = ('initial_t', 'mean'),     
                xbox = ('final_x', 'mean'),     
                ybox = ('final_y', 'mean'),        
                zbox = ('final_z', 'mean'),        # z in the box is the y mean
                nbox = ('final_z', 'count'),
                  ).reset_index()
    
    return gdf

# %%
def pixelated(gdfx,mcrst,sx,sy,sz, ecut, case='pixel'):
    gdf = voxelize(gdfx,mcrst,sx,sy,sz, ecut)
    gdf =gdf[gdf.ebox >ecut]
    return event_size(gdf)

# %%
def streams(gdx):
    gdf  = gdx.copy()
    grdf = gdf.groupby('event_id')
    gdf  = grdf.agg(#event_id = ('event_id', 'first'),
                etot = ('ebox', 'sum'),
                ngama = ('ebox', 'count')
                  ).reset_index()

    df1g = gdf[gdf.ngama==1]
    df2g = gdf[gdf.ngama==2]
    dfng = gdf[gdf.ngama>2]
    print(f" fraction of events 1g = {(event_size(df1g)/event_size(gdf)):.2f}")
    print(f" fraction of events 2g = {(event_size(df2g)/event_size(gdf)):.2f}")
    print(f" fraction of events >3g = {(event_size(dfng)/event_size(gdf)):.2f}")
    return df1g,df2g,dfng

# %% [markdown]
# ## Globals

# %%
path_to_data="/Users/jjgomezcadenas/Data/monolith/GammaMonolithicTest"

# %%
npr=10
eth = 0.001 # in keV
lmax = 100 # in mm

# %% [markdown]
# ## Code

# %%
file = os.path.join(path_to_data,"GammaMonolithicTestCsI.h5")

# %%
gammas = pd.read_hdf(file,"MC/particles")

# %%
gammas.head(npr)
# Out:
#    event_id  particle_id particle_name  primary  mother_id  initial_x  \
# 0         0            2            e-        0          1 -17.736462
# 1         0            1         gamma        1          0 -17.736462
# 2         1            1         gamma        1          0 -12.356936
# 3         1            4            e-        0          1 -12.356936
# 4         1            3         gamma        0          1 -12.356936
# 5         1          561            e-        0          3 -12.327125
# 6         1          560            e-        0          3 -12.327125
# 7         1            2            e-        0          1 -12.356936
# 8         2            2            e-        0          1 -23.710814
# 9         2            1         gamma        1          0 -23.710814
#
#    initial_y  initial_z  initial_t       final_x  ...  initial_momentum_x  \
# 0   5.652053  29.634308   0.117543    -17.765514  ...            0.209471
# 1   5.652053  -5.604053   0.000000 -12500.000000  ...            0.000000
# 2  -1.224260  -5.755552   0.000000    -12.356936  ...            0.000000
# 3  -1.224260  23.614937   0.097969    -12.356945  ...            0.022976
# 4  -1.224260  23.614937   0.097969    -12.327125  ...            0.005201
# 5  -1.398317  23.596510   0.098562    -12.327134  ...           -0.049781
# 6  -1.398317  23.596510   0.098562    -12.325269  ...            0.113699
# 7  -1.224260  23.614937   0.097969    -12.290342  ...           -0.436731
# 8  14.056176  26.735538   0.109050    -23.708187  ...            0.181543
# 9  14.056176  -5.956709   0.000000  -5618.885742  ...            0.000000
#
#    initial_momentum_y  initial_momentum_z final_momentum_x final_momentum_y  \
# 0            0.195723            0.335810         0.000000         -0.00000
# 1            0.000000            0.511000        -0.213009         -0.21135
# 2            0.000000            0.511000         0.000000          0.00000
# 3           -0.052433           -0.018800        -0.000000          0.00000
# 4           -0.030369           -0.003215         0.000000         -0.00000
# 5           -0.037946            0.009293         0.000000         -0.00000
# 6           -0.071204            0.094965         0.000000          0.00000
# 7           -0.314531            0.649181        -0.000000         -0.00000
# 8           -0.100990            0.100611         0.000000          0.00000
# 9            0.000000            0.511000        -0.183772          0.10158
#
#    final_momentum_z  kin_energy        length  creator_proc      final_proc
# 0          0.000000    0.164333      0.127115         compt       NoProcess
# 1          0.172129    0.511000  20306.849609          none  Transportation
# 2          0.000000    0.511000     29.370489          none            phot
# 3          0.000000    0.003540      0.000177          phot       NoProcess
# 4         -0.000000    0.030979      0.177550          phot            phot
# 5         -0.000000    0.003903      0.000222          phot       NoProcess
# 6         -0.000000    0.025784      0.005863          phot       NoProcess
# 7          0.000000    0.475013      0.539498          phot       NoProcess
# 8          0.000000    0.049714      0.014730         compt       NoProcess
# 9          0.409682    0.511000  14048.872070          none  Transportation
#
# [10 rows x 25 columns]

# %% [markdown]
# ### Simplify the original df dropping unneeded columns

# %%
gdf0 = gammas.drop(['initial_momentum_x', 'initial_momentum_y', 'initial_momentum_z',
                 'final_momentum_x', 'final_momentum_y', 'final_momentum_z',
                'final_proc', 'final_t'], axis=1)
gdf0.head(npr)
# Out:
#    event_id  particle_id particle_name  primary  mother_id  initial_x  \
# 0         0            2            e-        0          1 -17.736462
# 1         0            1         gamma        1          0 -17.736462
# 2         1            1         gamma        1          0 -12.356936
# 3         1            4            e-        0          1 -12.356936
# 4         1            3         gamma        0          1 -12.356936
# 5         1          561            e-        0          3 -12.327125
# 6         1          560            e-        0          3 -12.327125
# 7         1            2            e-        0          1 -12.356936
# 8         2            2            e-        0          1 -23.710814
# 9         2            1         gamma        1          0 -23.710814
#
#    initial_y  initial_z  initial_t       final_x       final_y       final_z  \
# 0   5.652053  29.634308   0.117543    -17.765514      5.679379     29.629778
# 1   5.652053  -5.604053   0.000000 -12500.000000 -12379.395508  10116.355469
# 2  -1.224260  -5.755552   0.000000    -12.356936     -1.224260     23.614937
# 3  -1.224260  23.614937   0.097969    -12.356945     -1.224278     23.614943
# 4  -1.224260  23.614937   0.097969    -12.327125     -1.398317     23.596510
# 5  -1.398317  23.596510   0.098562    -12.327134     -1.398394     23.596550
# 6  -1.398317  23.596510   0.098562    -12.325269     -1.398396     23.598791
# 7  -1.224260  23.614937   0.097969    -12.290342     -1.233843     23.598602
# 8  14.056176  26.735538   0.109050    -23.708187     14.053945     26.735806
# 9  14.056176  -5.956709   0.000000  -5618.885742   3106.785645  12500.000000
#
#   initial_volume final_volume  kin_energy        length creator_proc
# 0        CRYSTAL      CRYSTAL    0.164333      0.127115        compt
# 1            LAB        WORLD    0.511000  20306.849609         none
# 2            LAB      CRYSTAL    0.511000     29.370489         none
# 3        CRYSTAL      CRYSTAL    0.003540      0.000177         phot
# 4        CRYSTAL      CRYSTAL    0.030979      0.177550         phot
# 5        CRYSTAL      CRYSTAL    0.003903      0.000222         phot
# 6        CRYSTAL      CRYSTAL    0.025784      0.005863         phot
# 7        CRYSTAL      CRYSTAL    0.475013      0.539498         phot
# 8        CRYSTAL      CRYSTAL    0.049714      0.014730        compt
# 9            LAB        WORLD    0.511000  14048.872070         none

# %% [markdown]
# ### Compute fraction of gammas that interact in crsytal

# %%
g0 = gdf0[gdf0['mother_id'] == 0]
g0c = g0[g0['final_volume'] == 'CRYSTAL']
rg = len(g0c)/len(g0)
print(f"gammas crystal/gammas total = {rg}")
# Out:
# gammas crystal/gammas total = 0.6456248396202207

# %%
g0c.head(npr)
# Out:
#      event_id  particle_id particle_name  primary  mother_id  initial_x  \
# 2           1            1         gamma        1          0 -12.356936
# 12          3            1         gamma        1          0 -22.940617
# 20          4            1         gamma        1          0 -22.427443
# 39         10            1         gamma        1          0  21.776773
# 49         12            1         gamma        1          0 -21.764141
# 64         14            1         gamma        1          0   9.259459
# 70         15            1         gamma        1          0   8.795779
# 84         17            1         gamma        1          0   4.051988
# 94         18            1         gamma        1          0  -7.932999
# 102        19            1         gamma        1          0  11.330837
#
#      initial_y  initial_z  initial_t    final_x    final_y    final_z  \
# 2    -1.224260  -5.755552        0.0 -12.356936  -1.224260  23.614937
# 12   -6.074331  -5.982762        0.0 -18.776112  -2.697741  30.735048
# 20   22.119202  -6.216849        0.0 -23.930981  22.766039  18.060705
# 39    3.627890  -6.108748        0.0  21.776773   3.627890  16.771034
# 49  -17.572363  -6.154243        0.0 -15.363505 -12.424021  18.814552
# 64   20.987041  -6.078486        0.0  21.165886  23.097494  34.071846
# 70  -17.266539  -6.381431        0.0   8.795779 -17.266539  34.413074
# 84   19.556702  -5.800079        0.0   4.407465  15.841385  21.858204
# 94  -14.406339  -5.775762        0.0  -9.526190 -18.132849  15.469952
# 102   3.414835  -6.302588        0.0  -0.912930  -0.412004  45.394703
#
#     initial_volume final_volume  kin_energy     length creator_proc
# 2              LAB      CRYSTAL       0.511  29.370489         none
# 12             LAB      CRYSTAL       0.511  40.809826         none
# 20             LAB      CRYSTAL       0.511  29.118313         none
# 39             LAB      CRYSTAL       0.511  22.879782         none
# 49             LAB      CRYSTAL       0.511  30.562170         none
# 64             LAB      CRYSTAL       0.511  44.391243         none
# 70             LAB      CRYSTAL       0.511  40.794502         none
# 84             LAB      CRYSTAL       0.511  30.648090         none
# 94             LAB      CRYSTAL       0.511  48.302418         none
# 102            LAB      CRYSTAL       0.511  55.189869         none

# %%
b, e = histoplot(g0c.length, "length (mm)", "entries", bins=100, figsize=(4,4), 
                 title="gammas path length in crystal")

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,4))

hxy =ax[0].hist2d(g0c.initial_x, g0c.initial_y, cmap="viridis",bins=10)
#ax[0].set_aspect('equal')
ax[0].set_xlabel('x (mm)')
ax[0].set_ylabel('y (mm)')
ax[0].set_title(' x vs y gamma interactions')

hxz =ax[1].hist2d(g0c.initial_x, g0c.initial_z, cmap="viridis",bins=10)
#ax[1].set_aspect('equal')
ax[1].set_xlabel('x (mm)')
ax[1].set_ylabel('z (mm)')
ax[1].set_title(' x vs z gamma interactions')
# Out:
# Text(0.5, 1.0, ' x vs z gamma interactions')

# %% [markdown]
# ### Select events in which gammas interact in crystal

# %%
filter_gammas_in_crystal = True

# %%
if filter_gammas_in_crystal:
    grdf = gdf0.groupby('event_id')
    gdf1 = grdf.filter(lambda x: ((x.mother_id == 0) & (x['final_volume'] == 'CRYSTAL')).any() )
else:
    gdf1 = gdf0

# %%
gdf1.head(npr)
# Out:
#     event_id  particle_id particle_name  primary  mother_id  initial_x  \
# 2          1            1         gamma        1          0 -12.356936
# 3          1            4            e-        0          1 -12.356936
# 4          1            3         gamma        0          1 -12.356936
# 5          1          561            e-        0          3 -12.327125
# 6          1          560            e-        0          3 -12.327125
# 7          1            2            e-        0          1 -12.356936
# 10         3            2            e-        0          1 -22.940617
# 11         3        17878            e-        0          1 -18.624298
# 12         3            1         gamma        1          0 -22.940617
# 13         3        37711            e-        0          1 -18.776112
#
#     initial_y  initial_z  initial_t    final_x   final_y    final_z  \
# 2   -1.224260  -5.755552   0.000000 -12.356936 -1.224260  23.614937
# 3   -1.224260  23.614937   0.097969 -12.356945 -1.224278  23.614943
# 4   -1.224260  23.614937   0.097969 -12.327125 -1.398317  23.596510
# 5   -1.398317  23.596510   0.098562 -12.327134 -1.398394  23.596550
# 6   -1.398317  23.596510   0.098562 -12.325269 -1.398396  23.598791
# 7   -1.224260  23.614937   0.097969 -12.290342 -1.233843  23.598602
# 10  -6.074331  25.743437   0.105827 -22.959177 -6.028592  25.752043
# 11  -1.488481  29.427204   0.130164 -18.596409 -1.496239  29.408428
# 12  -6.074331  -5.982762   0.000000 -18.776112 -2.697741  30.735048
# 13  -2.697741  30.735048   0.136127 -18.776150 -2.697742  30.735048
#
#    initial_volume final_volume  kin_energy     length creator_proc
# 2             LAB      CRYSTAL    0.511000  29.370489         none
# 3         CRYSTAL      CRYSTAL    0.003540   0.000177         phot
# 4         CRYSTAL      CRYSTAL    0.030979   0.177550         phot
# 5         CRYSTAL      CRYSTAL    0.003903   0.000222         phot
# 6         CRYSTAL      CRYSTAL    0.025784   0.005863         phot
# 7         CRYSTAL      CRYSTAL    0.475013   0.539498         phot
# 10        CRYSTAL      CRYSTAL    0.177790   0.123518        compt
# 11        CRYSTAL      CRYSTAL    0.194258   0.150796        compt
# 12            LAB      CRYSTAL    0.511000  40.809826         none
# 13        CRYSTAL      CRYSTAL    0.002757   0.000171         phot

# %%
event_size(gdf1)/event_size(gdf0)
# Out:
# 0.6456248396202207

# %% [markdown]
# ### Remove primary gammas from dataframe

# %%
gdf2 = gdf1[gdf1['mother_id'] != 0]
gdf2.head(npr)
# Out:
#     event_id  particle_id particle_name  primary  mother_id  initial_x  \
# 3          1            4            e-        0          1 -12.356936
# 4          1            3         gamma        0          1 -12.356936
# 5          1          561            e-        0          3 -12.327125
# 6          1          560            e-        0          3 -12.327125
# 7          1            2            e-        0          1 -12.356936
# 10         3            2            e-        0          1 -22.940617
# 11         3        17878            e-        0          1 -18.624298
# 13         3        37711            e-        0          1 -18.776112
# 14         3        37709         gamma        0          1 -18.776112
# 15         3        38211            e-        0      37709 -18.705000
#
#     initial_y  initial_z  initial_t    final_x   final_y    final_z  \
# 3   -1.224260  23.614937   0.097969 -12.356945 -1.224278  23.614943
# 4   -1.224260  23.614937   0.097969 -12.327125 -1.398317  23.596510
# 5   -1.398317  23.596510   0.098562 -12.327134 -1.398394  23.596550
# 6   -1.398317  23.596510   0.098562 -12.325269 -1.398396  23.598791
# 7   -1.224260  23.614937   0.097969 -12.290342 -1.233843  23.598602
# 10  -6.074331  25.743437   0.105827 -22.959177 -6.028592  25.752043
# 11  -1.488481  29.427204   0.130164 -18.596409 -1.496239  29.408428
# 13  -2.697741  30.735048   0.136127 -18.776150 -2.697742  30.735048
# 14  -2.697741  30.735048   0.136127 -18.705000 -2.698852  30.749388
# 15  -2.698852  30.749388   0.136369 -18.704988 -2.698896  30.749430
#
#    initial_volume final_volume  kin_energy    length creator_proc
# 3         CRYSTAL      CRYSTAL    0.003540  0.000177         phot
# 4         CRYSTAL      CRYSTAL    0.030979  0.177550         phot
# 5         CRYSTAL      CRYSTAL    0.003903  0.000222         phot
# 6         CRYSTAL      CRYSTAL    0.025784  0.005863         phot
# 7         CRYSTAL      CRYSTAL    0.475013  0.539498         phot
# 10        CRYSTAL      CRYSTAL    0.177790  0.123518        compt
# 11        CRYSTAL      CRYSTAL    0.194258  0.150796        compt
# 13        CRYSTAL      CRYSTAL    0.002757  0.000171         phot
# 14        CRYSTAL      CRYSTAL    0.028306  0.072552         phot
# 15        CRYSTAL      CRYSTAL    0.003587  0.000262         phot

# %%
event_size(gdf2)/event_size(gdf0)
# Out:
# 0.6456248396202207

# %% [markdown]
# ## Energy conservation in dataframe

# %%
b, e = histoplot(event_ekin(gdf2), 'energy (MeV)', "entries", bins=100, figsize=(4,4))

# %% [markdown]
# #### Energy not conserved
# - This is due to double counting in geant4 track list
# - Can be fixed gettin rid of tracks with mother_id !=1

# %%
grdf = gdf2.groupby('event_id')
gdf3 = grdf.apply(lambda x: x[x['mother_id'] == 1]).reset_index(drop=True)
gdf3.head(npr)
# Out:
#    event_id  particle_id particle_name  primary  mother_id  initial_x  \
# 0         1            4            e-        0          1 -12.356936
# 1         1            3         gamma        0          1 -12.356936
# 2         1            2            e-        0          1 -12.356936
# 3         3            2            e-        0          1 -22.940617
# 4         3        17878            e-        0          1 -18.624298
# 5         3        37711            e-        0          1 -18.776112
# 6         3        37709         gamma        0          1 -18.776112
# 7         3        37708            e-        0          1 -18.776112
# 8         4            2            e-        0          1 -22.427443
# 9         4         3685            e-        0          1 -22.611578
#
#    initial_y  initial_z  initial_t    final_x    final_y    final_z  \
# 0  -1.224260  23.614937   0.097969 -12.356945  -1.224278  23.614943
# 1  -1.224260  23.614937   0.097969 -12.327125  -1.398317  23.596510
# 2  -1.224260  23.614937   0.097969 -12.290342  -1.233843  23.598602
# 3  -6.074331  25.743437   0.105827 -22.959177  -6.028592  25.752043
# 4  -1.488481  29.427204   0.130164 -18.596409  -1.496239  29.408428
# 5  -2.697741  30.735048   0.136127 -18.776150  -2.697742  30.735048
# 6  -2.697741  30.735048   0.136127 -18.705000  -2.698852  30.749388
# 7  -2.697741  30.735048   0.136127 -18.771688  -2.690413  30.747807
# 8  22.119202  18.769426   0.083345 -22.428923  22.120600  18.769791
# 9  21.608208  20.102449   0.088147 -22.629335  21.595926  20.238630
#
#   initial_volume final_volume  kin_energy    length creator_proc
# 0        CRYSTAL      CRYSTAL    0.003540  0.000177         phot
# 1        CRYSTAL      CRYSTAL    0.030979  0.177550         phot
# 2        CRYSTAL      CRYSTAL    0.475013  0.539498         phot
# 3        CRYSTAL      CRYSTAL    0.177790  0.123518        compt
# 4        CRYSTAL      CRYSTAL    0.194258  0.150796        compt
# 5        CRYSTAL      CRYSTAL    0.002757  0.000171         phot
# 6        CRYSTAL      CRYSTAL    0.028306  0.072552         phot
# 7        CRYSTAL      CRYSTAL    0.104485  0.057776         phot
# 8        CRYSTAL      CRYSTAL    0.037430  0.005277        compt
# 9        CRYSTAL      CRYSTAL    0.286827  0.260534        compt

# %%
b, e = histoplot(event_ekin(gdf3), 'energy (MeV)', "entries", bins=100, figsize=(6,6),
                title="Energy deposited in contained event")

# %%
grdf = gdf3.groupby('event_id')
group_sizes = grdf.size()
b, e = histoplot(group_sizes, 'number of particules', "entries", bins=50, figsize=(4,4),
                title="number of particles")

# %%
b, e = histoplot(gdf3.length, "length (mm)", "entries", bins=100, figsize=(4,4),
                title="track length")

# %% [markdown]
# ## Impose threshold in energy and length

# %%
gdf4 = gdf3[(gdf3['kin_energy'] >eth) & (gdf3.length<lmax)]
gdf4.head(npr)
# Out:
#    event_id  particle_id particle_name  primary  mother_id  initial_x  \
# 0         1            4            e-        0          1 -12.356936
# 1         1            3         gamma        0          1 -12.356936
# 2         1            2            e-        0          1 -12.356936
# 3         3            2            e-        0          1 -22.940617
# 4         3        17878            e-        0          1 -18.624298
# 5         3        37711            e-        0          1 -18.776112
# 6         3        37709         gamma        0          1 -18.776112
# 7         3        37708            e-        0          1 -18.776112
# 8         4            2            e-        0          1 -22.427443
# 9         4         3685            e-        0          1 -22.611578
#
#    initial_y  initial_z  initial_t    final_x    final_y    final_z  \
# 0  -1.224260  23.614937   0.097969 -12.356945  -1.224278  23.614943
# 1  -1.224260  23.614937   0.097969 -12.327125  -1.398317  23.596510
# 2  -1.224260  23.614937   0.097969 -12.290342  -1.233843  23.598602
# 3  -6.074331  25.743437   0.105827 -22.959177  -6.028592  25.752043
# 4  -1.488481  29.427204   0.130164 -18.596409  -1.496239  29.408428
# 5  -2.697741  30.735048   0.136127 -18.776150  -2.697742  30.735048
# 6  -2.697741  30.735048   0.136127 -18.705000  -2.698852  30.749388
# 7  -2.697741  30.735048   0.136127 -18.771688  -2.690413  30.747807
# 8  22.119202  18.769426   0.083345 -22.428923  22.120600  18.769791
# 9  21.608208  20.102449   0.088147 -22.629335  21.595926  20.238630
#
#   initial_volume final_volume  kin_energy    length creator_proc
# 0        CRYSTAL      CRYSTAL    0.003540  0.000177         phot
# 1        CRYSTAL      CRYSTAL    0.030979  0.177550         phot
# 2        CRYSTAL      CRYSTAL    0.475013  0.539498         phot
# 3        CRYSTAL      CRYSTAL    0.177790  0.123518        compt
# 4        CRYSTAL      CRYSTAL    0.194258  0.150796        compt
# 5        CRYSTAL      CRYSTAL    0.002757  0.000171         phot
# 6        CRYSTAL      CRYSTAL    0.028306  0.072552         phot
# 7        CRYSTAL      CRYSTAL    0.104485  0.057776         phot
# 8        CRYSTAL      CRYSTAL    0.037430  0.005277        compt
# 9        CRYSTAL      CRYSTAL    0.286827  0.260534        compt

# %%
b, e = histoplot(gdf4.length, "length (mm)", "entries", bins=100, figsize=(4,4), title="track length")

# %% [markdown]
# ### XYZ distributions

# %%
b, e = histoplot(gdf4.initial_z, "z (mm)", "entries", bins=100, figsize=(4,4),
                title="z distribution")

# %%
zmin = np.ceil(e[0])
zmax = np.floor(e[-1])
dz = zmax - zmin
print(f"zmax = {zmax:.2f}, zmin = {zmin:.2f}, dz = {dz:.2f}")
# Out:
# zmax = 50.00, zmin = 13.00, dz = 37.00

# %%
b, e = histoplot(gdf4.initial_x, "x (mm)", "entries", bins=100, figsize=(4,4),
                 title="x distribution")

# %%
xmin = -np.ceil(-e[0])
xmax = np.ceil(e[-1])
dx = xmax - xmin
print(f"xmax = {xmax:.2f}, xmin = {xmin:.2f}, dx = {dx:.2f}")
# Out:
# xmax = 24.00, xmin = -24.00, dx = 48.00

# %%
b, e = histoplot(gdf4.initial_y, "y (mm)", "entries", bins=100, figsize=(4,4),
                 title="y distribution")

# %%
ymin = -np.ceil(-e[0])
ymax = np.ceil(e[-1])
dy = ymax - ymin
print(f"ymax = {ymax:.2f}, ymin = {ymin:.2f}, dy = {dy:.2f}")
# Out:
# ymax = 25.00, ymin = -25.00, dy = 50.00

# %%
MCrst = namedtuple('MCrst','xmin xmax dx ymin ymax dy zmin zmax dz')
mcrst = MCrst(xmin, xmax, dx, ymin, ymax, dy, zmin, zmax, dz)
mcrst
# Out:
# MCrst(xmin=-24.0, xmax=24.0, dx=48.0, ymin=-25.0, ymax=25.0, dy=50.0, zmin=13.0, zmax=50.0, dz=37.0)

# %%
b, e = histoplot(event_ekin(gdf4), 'energy (MeV)', "entries", bins=100, figsize=(6,6),
                title="kinetic energy")

# %%
grdf = gdf4.groupby('event_id')
group_sizes = grdf.size()
b, e = histoplot(group_sizes, 'number of particules', "entries", bins=10, figsize=(4,4,),
                title="number of particles")

# %%
fce = event_size(gdf4)/event_size(gdf0)
print(f"Fraction of events contained in crystal = {(fce):.2f}")
# Out:
# Fraction of events contained in crystal = 0.65

# %%
gdf5 = gdf4.drop(['initial_x', 'initial_y', 'initial_z', 
                  'primary', 'mother_id', 'initial_volume', 'final_volume'], axis=1)
gdf5.head(npr)
# Out:
#    event_id  particle_id particle_name  initial_t    final_x    final_y  \
# 0         1            4            e-   0.097969 -12.356945  -1.224278
# 1         1            3         gamma   0.097969 -12.327125  -1.398317
# 2         1            2            e-   0.097969 -12.290342  -1.233843
# 3         3            2            e-   0.105827 -22.959177  -6.028592
# 4         3        17878            e-   0.130164 -18.596409  -1.496239
# 5         3        37711            e-   0.136127 -18.776150  -2.697742
# 6         3        37709         gamma   0.136127 -18.705000  -2.698852
# 7         3        37708            e-   0.136127 -18.771688  -2.690413
# 8         4            2            e-   0.083345 -22.428923  22.120600
# 9         4         3685            e-   0.088147 -22.629335  21.595926
#
#      final_z  kin_energy    length creator_proc
# 0  23.614943    0.003540  0.000177         phot
# 1  23.596510    0.030979  0.177550         phot
# 2  23.598602    0.475013  0.539498         phot
# 3  25.752043    0.177790  0.123518        compt
# 4  29.408428    0.194258  0.150796        compt
# 5  30.735048    0.002757  0.000171         phot
# 6  30.749388    0.028306  0.072552         phot
# 7  30.747807    0.104485  0.057776         phot
# 8  18.769791    0.037430  0.005277        compt
# 9  20.238630    0.286827  0.260534        compt

# %% [markdown]
# ## Classification of events

# %% [markdown]
# ### Select events in which the primary electron makes a photoelectric

# %%
grdf = gdf5.groupby('event_id')
gpe = grdf.filter(lambda x: ((x.particle_id == 2) & (x['creator_proc'] == 'phot')).any() )
gpe.head(npr)
# Out:
#     event_id  particle_id particle_name  initial_t    final_x    final_y  \
# 0          1            4            e-   0.097969 -12.356945  -1.224278
# 1          1            3         gamma   0.097969 -12.327125  -1.398317
# 2          1            2            e-   0.097969 -12.290342  -1.233843
# 13        10            4         gamma   0.076319  21.778830   3.626679
# 14        10            3         gamma   0.076319  21.690163   3.330573
# 15        10            2            e-   0.076319  21.905153   3.560991
# 25        15            4         gamma   0.136076   8.783142 -17.274261
# 26        15            3         gamma   0.136076   8.442817 -17.217295
# 27        15            2            e-   0.136076   8.809553 -17.193239
# 51        21            4            e-   0.101080  -3.358141   8.090915
#
#       final_z  kin_energy    length creator_proc
# 0   23.614943    0.003540  0.000177         phot
# 1   23.596510    0.030979  0.177550         phot
# 2   23.598602    0.475013  0.539498         phot
# 13  16.771116    0.004273  0.002387         phot
# 14  16.505219    0.030979  0.501098         phot
# 15  16.743124    0.475013  0.701540         phot
# 25  34.431221    0.003913  0.023425         phot
# 26  34.369698    0.028609  0.359010         phot
# 27  34.423046    0.477824  0.354008         phot
# 51  24.305965    0.004190  0.000383         phot

# %%
grdf = gpe.groupby('event_id')
group_sizes = grdf.size()
b, e = histoplot(group_sizes, 'number of particules', "entries", bins=10, figsize=(4,4),
                title="number of particles photoelectric")

# %%
b, e = histoplot(event_ekin(gpe), 'energy (MeV)', "entries", bins=100, figsize=(4,4),
                title="kinetic energy photoelectric")

# %%
fphe = event_size(gpe)/event_size(gdf4)
print(f"Fraction of photoelectric events = {(fphe):.2f}")
# Out:
# Fraction of photoelectric events = 0.33

# %% [markdown]
# ### Select Compton

# %%
grdf = gdf5.groupby('event_id')
gcomp = grdf.filter(lambda x: ((x.particle_id == 2) & (x['creator_proc'] == 'compt')).any() )
gcomp.head(npr)
# Out:
#     event_id  particle_id particle_name  initial_t    final_x    final_y  \
# 3          3            2            e-   0.105827 -22.959177  -6.028592
# 4          3        17878            e-   0.130164 -18.596409  -1.496239
# 5          3        37711            e-   0.136127 -18.776150  -2.697742
# 6          3        37709         gamma   0.136127 -18.705000  -2.698852
# 7          3        37708            e-   0.136127 -18.771688  -2.690413
# 8          4            2            e-   0.083345 -22.428923  22.120600
# 9          4         3685            e-   0.088147 -22.629335  21.595926
# 10         4        32506            e-   0.097128 -23.931005  22.766010
# 11         4        32505         gamma   0.097128 -23.726477  22.638563
# 12         4        32504            e-   0.097128 -23.933041  22.810606
#
#       final_z  kin_energy    length creator_proc
# 3   25.752043    0.177790  0.123518        compt
# 4   29.408428    0.194258  0.150796        compt
# 5   30.735048    0.002757  0.000171         phot
# 6   30.749388    0.028306  0.072552         phot
# 7   30.747807    0.104485  0.057776         phot
# 8   18.769791    0.037430  0.005277        compt
# 9   20.238630    0.286827  0.260534        compt
# 10  18.060688    0.003282  0.000149         phot
# 11  17.942863    0.030979  0.268251         phot
# 12  18.051018    0.149746  0.103043         phot

# %%
grdf = gcomp.groupby('event_id')
group_sizes = grdf.size()
b, e = histoplot(group_sizes, 'number of particules', "entries", bins=20, figsize=(4,4),
                title="number of particles Compton")

# %%
fcomp = event_size(gcomp)/event_size(gdf4)
print(f"Fraction of compton events = {(fcomp):.2f}")
# Out:
# Fraction of compton events = 0.67

# %% [markdown]
# ### Copy dataframe for later

# %%
gdx = gdf5.copy(deep=True)
gdy = gdf5.copy(deep=True)

# %% [markdown]
# ## Case of Pixelated crystal
# - Slice x,y in cells corresponding to the size of detector elements (e.g, 3x3 or 6x6)
# - no slice in z

# %%
sx = sy = 6 # in mm
sz = dz  # no slicing in z for now
nx = int(dx/sx)
ny = int(dy/sy)
nz = int(dz/sz)
print(f"nx = {nx}, ny = {ny}, nz = {nz}")
print(f"number of voxels = {nx*ny*nz}")
# Out:
# nx = 8, ny = 8, nz = 1
# number of voxels = 64

# %%
print(f"index for xmin ={xindex(xmin, sx)} index for xmax ={xindex(xmax, sx)}")
print(f"index for ymin ={yindex(ymin, sy)} index for ymax ={yindex(ymax, sy)}")
print(f"index for zmin ={zindex(zmin, sz)} index for zmax ={zindex(zmax, sz)}")
# Out:
# index for xmin =0.0 index for xmax =8.0
# index for ymin =0.0 index for ymax =8.0
# index for zmin =0.0 index for zmax =1.0

# %% [markdown]
# ### Add columns with the indexes to gdf5

# %%
gdf5["ix"]= xindex(gdf5.final_x.values, sx).astype(int)
gdf5["iy"]= yindex(gdf5.final_y.values, sy).astype(int)
gdf5["iz"]= zindex(gdf5.final_z.values, sz).astype(int)
gdf5.head(npr)
# Out:
#    event_id  particle_id particle_name  initial_t    final_x    final_y  \
# 0         1            4            e-   0.097969 -12.356945  -1.224278
# 1         1            3         gamma   0.097969 -12.327125  -1.398317
# 2         1            2            e-   0.097969 -12.290342  -1.233843
# 3         3            2            e-   0.105827 -22.959177  -6.028592
# 4         3        17878            e-   0.130164 -18.596409  -1.496239
# 5         3        37711            e-   0.136127 -18.776150  -2.697742
# 6         3        37709         gamma   0.136127 -18.705000  -2.698852
# 7         3        37708            e-   0.136127 -18.771688  -2.690413
# 8         4            2            e-   0.083345 -22.428923  22.120600
# 9         4         3685            e-   0.088147 -22.629335  21.595926
#
#      final_z  kin_energy    length creator_proc  ix  iy  iz
# 0  23.614943    0.003540  0.000177         phot   1   3   0
# 1  23.596510    0.030979  0.177550         phot   1   3   0
# 2  23.598602    0.475013  0.539498         phot   1   3   0
# 3  25.752043    0.177790  0.123518        compt   0   3   0
# 4  29.408428    0.194258  0.150796        compt   0   3   0
# 5  30.735048    0.002757  0.000171         phot   0   3   0
# 6  30.749388    0.028306  0.072552         phot   0   3   0
# 7  30.747807    0.104485  0.057776         phot   0   3   0
# 8  18.769791    0.037430  0.005277        compt   0   7   0
# 9  20.238630    0.286827  0.260534        compt   0   7   0

# %% [markdown]
# ### Group by event, ix & iy, and produce aggregate

# %%
grdf = gdf5.groupby(['event_id', 'ix', 'iy'])

# %%
gdf6 = grdf.agg(
                ebox = ('kin_energy', 'sum'),
                tbox = ('initial_t', 'mean'),     
                xbox = ('final_x', 'mean'),     
                ybox = ('final_y', 'mean'),        
                zbox = ('final_z', 'mean'),        # z in the box is the y mean
                nbox = ('final_z', 'count'),
                  ).reset_index()

# %%
gdf6.head(npr)
# Out:
#    event_id  ix  iy      ebox      tbox       xbox       ybox       zbox  nbox
# 0         1   1   3  0.509532  0.097969 -12.324803  -1.285479  23.603354     3
# 1         3   0   3  0.507597  0.128874 -19.561686  -3.122367  29.478542     5
# 2         4   0   7  0.508264  0.092575 -23.329756  22.386341  18.612598     5
# 3        10   7   4  0.510265  0.076319  21.791382   3.506081  16.673153     3
# 4        12   0   1  0.196762  0.072497 -21.746677 -17.568899  15.576235     1
# 5        12   1   2  0.313091  0.101944 -15.359886 -12.358227  18.806292     2
# 6        14   5   7  0.100251  0.083498   9.263078  20.982071  18.952204     3
# 7        14   7   7  0.376061  0.148073  21.183729  22.991249  34.159786     1
# 8        14   7   8  0.031653  0.148073  21.178696  23.115894  33.863358     2
# 9        15   5   1  0.510347  0.136076   8.678504 -17.228266  34.407990     3

# %%
b, e = histoplot(gdf6.ebox, "energy (keV)", "entries", bins=100, figsize=(4,4),
                title="energy in pixels")

# %%
b, e = histoplot(gdf6.nbox, "number of particles", "entries", bins=100, figsize=(4,4),
                title="number of particles summed in pixels")

# %%
evts, evts_size = np.unique(gdf6.event_id.values, return_counts=True)

# %%
b, e = histoplot(evts_size, "number of pixels", "entries", bins=10, figsize=(4,4),
                title="number of pixels with signal")

# %%
f1px = b[0]/np.sum(b)
print(f"fraction of events with 1 pixel lighted relative to total {(f1px):.2f}")
# Out:
# fraction of events with 1 pixel lighted relative to total 0.52

# %% [markdown]
# ## Select events (pixelated case)
# - Conditions:
# - Energy within 5 % of 511 keV
# - 1 pixel lighted

# %%
emin = 0.511 - 0.05*0.511
print(f"minimum energy: emin ={emin:.3f}")
# Out:
# minimum energy: emin =0.485

# %%
gdf7 =gdf6[gdf6.ebox >emin]

# %%
gdf7.head(npr)
# Out:
#     event_id  ix  iy      ebox      tbox       xbox       ybox       zbox  \
# 0          1   1   3  0.509532  0.097969 -12.324803  -1.285479  23.603354
# 1          3   0   3  0.507597  0.128874 -19.561686  -3.122367  29.478542
# 2          4   0   7  0.508264  0.092575 -23.329756  22.386341  18.612598
# 3         10   7   4  0.510265  0.076319  21.791382   3.506081  16.673153
# 9         15   5   1  0.510347  0.136076   8.678504 -17.228266  34.407990
# 13        18   2   1  0.487183  0.140669  -8.877740 -16.735569  20.175232
# 20        21   3   5  0.510182  0.101080  -3.393924   8.214833  24.242899
# 23        24   6   2  0.509780  0.169824  17.817398  -8.478578  44.687397
# 28        27   4   6  0.508390  0.130565   2.700473  13.440247  31.764900
# 32        31   5   7  0.510058  0.084356   6.334840  18.033068  19.449629
#
#     nbox
# 0      3
# 1      5
# 2      5
# 3      3
# 9      3
# 13     5
# 20     3
# 23     1
# 28     4
# 32     3

# %%
fpxecut = event_size(gdf7)/event_size(gdf6)
print(f"fraction of events pixelated detector with e > ecut {(fpxecut):.2f}")
# Out:
# fraction of events pixelated detector with e > ecut 0.53

# %%
fpxsel = event_size(gdf7)/event_size(gdf0)
print(f"fraction of selecte devents (wrt total events) pixelated detector: {(fpxsel):.2f}")
# Out:
# fraction of selecte devents (wrt total events) pixelated detector: 0.34

# %%
evts, evts_size = np.unique(gdf7.event_id.values, return_counts=True)
b, e = histoplot(evts_size, "number of lighted pixels", "entries", bins=10, figsize=(4,4),
                title="number of lighted pixels after ecut")

# %% [markdown]
# ### Comparison between 6x6 and 3x3

# %%
npxl3x3 = pixelated(gdy,mcrst,sx=3,sy=3,sz=dz, ecut=emin)
# Out:
# nx = 16, ny = 16, nz = 1
# number of voxels = 256
# index for xmin =0.0 index for xmax =16.0
# index for ymin =0.0 index for ymax =16.0
# index for zmin =0.0 index for zmax =1.0

# %%
fpxsel3x3 = npxl3x3/event_size(gdf0)
print(f"fraction of selected devents (wrt total events) pixelated 3x3 detector: {(fpxsel3x3):.2f}")
# Out:
# fraction of selected devents (wrt total events) pixelated 3x3 detector: 0.27

# %%
npxl6x6 = pixelated(gdy,mcrst,sx=6,sy=6,sz=dz,ecut=emin)
# Out:
# nx = 8, ny = 8, nz = 1
# number of voxels = 64
# index for xmin =0.0 index for xmax =8.0
# index for ymin =0.0 index for ymax =8.0
# index for zmin =0.0 index for zmax =1.0

# %%
fpxsel6x6 = npxl6x6/event_size(gdf0)
print(f"fraction of selected devents (wrt total events) pixelated 6x6 detector: {(fpxsel6x6):.2f}")
# Out:
# fraction of selected devents (wrt total events) pixelated 6x6 detector: 0.34

# %% [markdown]
# ## The case of monolithic crystal
#
# - slice in (x,y,z).
# - take the size of the slice equal to that of SiPM (e.g, 6x6)

# %%
gdm = gdx.copy()

# %%
gdm = voxelize(gdm,mcrst,sx=6,sy=6,sz=6,ecut=emin, case='mono')
# Out:
# nx = 8, ny = 8, nz = 6
# number of voxels = 384
# index for xmin =0.0 index for xmax =8.0
# index for ymin =0.0 index for ymax =8.0
# index for zmin =0.0 index for zmax =6.0

# %%
gdm.head(npr)
# Out:
#    event_id  ix  iy  iz      ebox      tbox       xbox       ybox       zbox  \
# 0         1   1   3   1  0.509532  0.097969 -12.324803  -1.285479  23.603354
# 1         3   0   3   2  0.507597  0.128874 -19.561686  -3.122367  29.478542
# 2         4   0   7   0  0.221437  0.093682 -23.504862  22.583944  18.206089
# 3         4   0   7   1  0.286827  0.088147 -22.629335  21.595926  20.238630
# 4        10   7   4   0  0.510265  0.076319  21.791382   3.506081  16.673153
# 5        12   0   1   0  0.196762  0.072497 -21.746677 -17.568899  15.576235
# 6        12   1   2   0  0.313091  0.101944 -15.359886 -12.358227  18.806292
# 7        14   5   7   0  0.100251  0.083498   9.263078  20.982071  18.952204
# 8        14   7   7   3  0.376061  0.148073  21.183729  22.991249  34.159786
# 9        14   7   8   3  0.031653  0.148073  21.178696  23.115894  33.863358
#
#    nbox
# 0     3
# 1     5
# 2     4
# 3     1
# 4     3
# 5     1
# 6     2
# 7     3
# 8     1
# 9     2

# %%
b, e = histoplot(gdm.ebox, "energy (keV)", "entries", bins=100, figsize=(4,4),
                title="ebox energy mnolithic")

# %%
evts, evts_size = np.unique(gdm.event_id.values, return_counts=True)
b, e = histoplot(evts_size, "number of pixels", "entries", bins=5, figsize=(4,4),
                title="number of lighted pixels monolithic crystal")

# %%
f1c = b[0]/np.sum(b)
f2c = b[1]/np.sum(b)
f3c = b[2]/np.sum(b)
print(f"fractions: 1 cluster ={f1c:.2f}")
print(f"fractions: 2 cluster ={f2c:.2f}")
print(f"fractions: 3 cluster ={f3c:.2f}")
# Out:
# fractions: 1 cluster =0.45
# fractions: 2 cluster =0.38
# fractions: 3 cluster =0.14

# %% [markdown]
# ## Split data into three streams.
# - Stream 1g: events with 1 cluster: true information: x,y,z,t,e
# - Stream 2g: events with 2 clusters: true information: x1,y1,z1,t1,e1, x2,y2,z2,t2,e2
# - Stream ng: events with more than 2 clusters: no true information needed
#
# #### Strategy:
# - First classify events as 1g, 2g or ng. This requires training a CNN with events of categories 1g, 2g, ng.
# - Output of the net decides type of event.
# - if 1g pass event through a second net trained with events of type 1g and find x,y,z.
# - if 2g pass event through a second net trained with events of type 2g and find (x,y,z)_1,2
# - if ng reject event

# %%
event_size(gdm)/event_size(gdf0)
# Out:
# 0.6456248396202207

# %%
df1g,df2g,dfng = streams(gdm)
# Out:
#  fraction of events 1g = 0.45
#  fraction of events 2g = 0.38
#  fraction of events >3g = 0.17

# %%
gdmx = gdm.drop(['ix', 'iy', 'iz', 
                  'tbox', 'nbox'], axis=1)
gdmx.head(npr)
# Out:
#    event_id      ebox       xbox       ybox       zbox
# 0         1  0.509532 -12.324803  -1.285479  23.603354
# 1         3  0.507597 -19.561686  -3.122367  29.478542
# 2         4  0.221437 -23.504862  22.583944  18.206089
# 3         4  0.286827 -22.629335  21.595926  20.238630
# 4        10  0.510265  21.791382   3.506081  16.673153
# 5        12  0.196762 -21.746677 -17.568899  15.576235
# 6        12  0.313091 -15.359886 -12.358227  18.806292
# 7        14  0.100251   9.263078  20.982071  18.952204
# 8        14  0.376061  21.183729  22.991249  34.159786
# 9        14  0.031653  21.178696  23.115894  33.863358

# %%
gdm1c = gdmx[gdmx['event_id'].isin(df1g.event_id.values)]
gdm1c.head(npr)
# Out:
#     event_id      ebox       xbox       ybox       zbox
# 0          1  0.509532 -12.324803  -1.285479  23.603354
# 1          3  0.507597 -19.561686  -3.122367  29.478542
# 4         10  0.510265  21.791382   3.506081  16.673153
# 10        15  0.510347   8.678504 -17.228266  34.407990
# 23        21  0.510182  -3.393924   8.214833  24.242899
# 26        24  0.509780  17.817398  -8.478578  44.687397
# 36        31  0.510058   6.334840  18.033068  19.449629
# 42        34  0.509274  13.018387  15.764901  46.338161
# 45        36  0.509532 -18.509888 -15.362767  43.620972
# 69        54  0.510118  -4.917354 -10.481607  16.285175

# %%
gdm2c = gdmx[gdmx['event_id'].isin(df2g.event_id.values)]
gdm2c.head(npr)
# Out:
#     event_id      ebox       xbox       ybox       zbox
# 2          4  0.221437 -23.504862  22.583944  18.206089
# 3          4  0.286827 -22.629335  21.595926  20.238630
# 5         12  0.196762 -21.746677 -17.568899  15.576235
# 6         12  0.313091 -15.359886 -12.358227  18.806292
# 24        22  0.213324  17.179495  -1.924621  14.857929
# 25        22  0.295461  17.948851   1.561837  16.291643
# 27        25  0.317640 -15.019795  -1.242328  22.377869
# 28        25  0.192617 -10.413887   2.409485  17.253313
# 29        26  0.419663   2.998995  13.721797  39.855122
# 30        26  0.090147   7.904878  13.587720  35.437347

# %%
gdmnc = gdmx[gdmx['event_id'].isin(dfng.event_id.values)]
gdmnc.head(npr)
# Out:
#     event_id      ebox       xbox       ybox       zbox
# 7         14  0.100251   9.263078  20.982071  18.952204
# 8         14  0.376061  21.183729  22.991249  34.159786
# 9         14  0.031653  21.178696  23.115894  33.863358
# 11        17  0.077242   4.407759  15.842754  21.856821
# 12        17  0.340380   4.157046  19.497139  17.763126
# 13        17  0.088952   5.802333  17.565784  20.993097
# 14        18  0.019191  -8.136803 -21.031120  18.813810
# 15        18  0.183522  -9.532592 -18.319399  15.451363
# 16        18  0.303661  -7.895463 -14.359824  27.261036
# 17        19  0.434288  -0.698718  -0.484844  45.347191

# %% [markdown]
# ## Two cluster case

# %%
grdf = gdm2c.groupby('event_id')
gdy2ca = grdf.agg(#event_id = ('event_id', 'first'),
                etot = ('ebox', 'sum'),
                e1 = ('ebox', 'first'),
                e2 = ('ebox', 'last'),
                x1 = ('xbox', 'first'),
                x2 = ('xbox', 'last'),
                y1 = ('ybox', 'first'),
                y2 = ('ybox', 'last'),
                z1 = ('zbox', 'first'),
                z2 = ('zbox', 'last')
                  ).reset_index()

# %%
gdy2ca
# Out:
#      event_id      etot        e1        e2         x1         x2         y1  \
# 0           4  0.508264  0.221437  0.286827 -23.504862 -22.629335  22.583944
# 1          12  0.509853  0.196762  0.313091 -21.746677 -15.359886 -17.568899
# 2          22  0.508785  0.213324  0.295461  17.179495  17.948851  -1.924621
# 3          25  0.510257  0.317640  0.192617 -15.019795 -10.413887  -1.242328
# 4          26  0.509810  0.419663  0.090147   2.998995   7.904878  13.721797
# ..        ...       ...       ...       ...        ...        ...        ...
# 940      3872  0.507010  0.342214  0.164796  -9.737653  -7.078852  13.152273
# 941      3882  0.509562  0.028609  0.480952   4.645298   4.556379 -19.103146
# 942      3889  0.508052  0.029236  0.478816 -11.660211 -10.561278   1.886710
# 943      3891  0.509356  0.216075  0.293281 -21.633266 -19.607063 -21.228594
# 944      3892  0.507765  0.047768  0.459997  -6.019348  -2.222922  -2.332653
#
#             y2         z1         z2
# 0    21.595926  18.206089  20.238630
# 1   -12.358227  15.576235  18.806292
# 2     1.561837  14.857929  16.291643
# 3     2.409485  22.377869  17.253313
# 4    13.587720  39.855122  35.437347
# ..         ...        ...        ...
# 940  11.693000  16.883734  23.722748
# 941 -18.647085  12.618118  13.483722
# 942   5.158408  27.451233  36.165478
# 943 -13.773992  17.996925  19.961136
# 944  -3.269346  14.098227  16.384798
#
# [945 rows x 10 columns]

# %%
fig, ax = plt.subplots(2, 2, figsize=(10,10))

hxy =ax[0,0].hist2d(gdy2ca.x1, gdy2ca.x2, cmap="viridis",bins=10)
#ax[0].set_aspect('equal')
ax[0,0].set_xlabel('x1 (mm)')
ax[0,0].set_ylabel('x2 (mm)')

hxz =ax[0,1].hist2d(gdy2ca.y1, gdy2ca.y2, cmap="viridis",bins=10)
#ax[1].set_aspect('equal')
ax[0,1].set_xlabel('y1 (mm)')
ax[0,1].set_ylabel('y2 (mm)')

hxz =ax[1,0].hist2d(gdy2ca.z1, gdy2ca.z2, cmap="viridis",bins=10)
#ax[1].set_aspect('equal')
ax[1,0].set_xlabel('z1 (mm)')
ax[1,0].set_ylabel('z2 (mm)')

hxz =ax[1,1].hist2d(gdy2ca.e1, gdy2ca.e2, cmap="viridis",bins=10)
#ax[1].set_aspect('equal')
ax[1,1].set_xlabel('e1 (mm)')
ax[1,1].set_ylabel('e2 (mm)')
# Out:
# Text(0, 0.5, 'e2 (mm)')
